# %% [markdown]
# # Session 10 — Training Loop Truth Harness
#
# Run the executable harness below. It prints every key tensor shape, verifies a gradient against a finite difference, compares naive and token-weighted gradient accumulation, logs gradient norms, computes MFU inputs, and decodes 0.1 in FP32/BF16/FP8 E4M3.

# %%
from pathlib import Path
import runpy
runpy.run_path(str(Path('training_harness.py')), run_name='__main__')
